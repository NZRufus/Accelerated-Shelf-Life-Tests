# %%
import numpy as np
from numpy import sum as arraysum
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
df=pd.read_csv("Z:\\Tech Development\\Tech Development projects\\EM-089 Application Of Arrhenius Equation - for HbA1c products\\Results\\Arr6.csv")

# %%
df.head()
# Out:
#       inv_T  Days      Ln_k     Lot  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  3.047387   1.5  0.405465  4182.0         NaN         NaN         NaN
# 1  3.143171   8.0  2.197225  4182.0         NaN         NaN         NaN
# 2  3.245173  21.0  3.044522  4182.0         NaN         NaN         NaN
# 3  3.354016  77.0  4.343805  4182.0         NaN         NaN         NaN
# 4  3.047387   5.0  1.609438  7089.0         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
sns.set(style="ticks", color_codes=True, font_scale =1)
plt.xlim([3,3.6])
sns.set(rc={'figure.figsize':(10,10)}) 
g=sns.regplot(x='inv_T', y='Ln_k', data=df.query("Lot==4182"), ci=95, color='r', fit_reg=True)
plt.ylim([0,10])
plt.axvline((3.5568), ls=(0, (5, 5)), c="blue")
plt.axhline((6.9363), ls=(0, (5, 5)), c="blue")
plt.xlabel("1/T *1E03 (1/K)", fontweight='bold', size=16)
plt.ylabel("Ln_k",fontweight='bold', size=16 )
plt.title("Arrhenius Plot for Batch 4182", fontweight='bold', size=16)
plt.savefig("Arr_4182_Final")
plt.show()

# %%
sns.set(style="ticks", color_codes=True, font_scale =1)
plt.xlim([3,3.6])
sns.set(rc={'figure.figsize':(10,10)}) 
g=sns.regplot(x='inv_T', y='Ln_k', data=df.query("Lot==7089"), ci=95, color='r', fit_reg=True)
plt.ylim([0,10])
plt.axvline((3.5568), ls=(0, (5, 5)), c="blue")
plt.axhline((7.8922), ls=(0, (5, 5)), c="blue")
plt.xlabel("1/T *1E03 (1/K)", fontweight='bold', size=16)
plt.ylabel("Ln_k",fontweight='bold', size=16)
plt.title("Arrhenius Plot for Batch 7089", fontweight='bold', size=16)
plt.savefig("Arr_7089_Final1")
plt.show()

# %%
df1=pd.read_csv("Z:\\Tech Development\\Tech Development projects\\EM-089 Application Of Arrhenius Equation - for HbA1c products\\Results\\Arr7.csv")

# %%
sns.set(style="ticks", color_codes=True, font_scale =1)
plt.xlim([3,3.6])
sns.set(rc={'figure.figsize':(5,5)}) 
g=sns.regplot(x='inv_T', y='Ln_k', data=df1.query("Lot==4182"), ci=95, color='r', fit_reg=True)
plt.ylim([-10,-2])
plt.xlabel("1/T *1E03 (1/K)", fontweight='bold', size=16)
plt.ylabel("Ln_k",fontweight='bold', size=16)
plt.title("Batch 4182", fontweight='bold', size=16)
plt.savefig("Arr_4182_Final2")
plt.show()

# %%
sns.set(style="ticks", color_codes=True, font_scale =1)
plt.xlim([3,3.6])
sns.set(rc={'figure.figsize':(5,5)}) 
g=sns.regplot(x='inv_T', y='Ln_k', data=df1.query("Lot==7089"), ci=95, color='r', fit_reg=True)
plt.ylim([-10,-2])
plt.xlabel("1/T *1E03 (1/K)", fontweight='bold', size=16)
plt.ylabel("Ln_k",fontweight='bold', size=16)
plt.title("Batch 7089", fontweight='bold', size=16)
plt.savefig("Arr_7089_Final2")
plt.show()
